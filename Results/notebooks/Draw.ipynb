# %%
import matplotlib.pyplot as plt

# %%
# Data
languages = [
    "ASM - MASM x64 v14.38.33133.0", "ASM - NASM x64 v2.16.01",
    "C++ MSVC x64 v19.38.33133 / Linker v14.38.33133.0", "DotnetCore v8.0.100",
    "Cython v3.0.7", "Cython Full v3.0.7",
    "Javascript - nodeJS v21.5.0", "TypeScript - compiled v21.5.0",
    "TypeScript ts-node v5.3.3", "PyPy v7.3.14 with MSC v.1929 with python v3.10.13",
    "Firefox v122.0b4", "TypeScript compiled Firefox v122.0b4",
    "Python 3.12.1"
]
execution_times = [
    0.1893, 0.1894,
    1.0028, 1.0029,
    1.0045, 1.0047,
    2.74, 3.20,
    3.20, 7.734,
    9.775, 9.87,
    27.09
]

# Adjusting the color to depend on execution times
colors = plt.cm.jet([x/max(execution_times) for x in execution_times])

# Creating the histogram with colors based on execution times
fig, ax = plt.subplots(figsize=(10, 8))
bars = ax.barh(languages, execution_times, color=colors)
plt.xlabel('Execution Time (s)')
plt.ylabel('Language / Framework')
plt.title('Execution Time Comparison')
plt.colorbar(plt.cm.ScalarMappable(cmap='jet', norm=plt.Normalize(vmin=min(execution_times), vmax=max(execution_times))), label='Execution Time (s)', ax=ax)
plt.tight_layout()

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

languages = [
    "ASM - MASM x64 v14.38.33133.0", "ASM - NASM x64 v2.16.01",
    "C++ MSVC x64 v19.38.33133 / Linker v14.38.33133.0", "DotnetCore v8.0.100",
    "Cython v3.0.7", "Cython Full v3.0.7",
    "Javascript - nodeJS v21.5.0", "TypeScript - compiled v21.5.0",
    "TypeScript ts-node v5.3.3", "PyPy v7.3.14 with MSC v.1929 with python v3.10.13",
    "Firefox v122.0b4", "TypeScript compiled Firefox v122.0b4",
    "Python 3.12.1"
]
execution_times = [
    0.1893, 0.1894,
    1.0028, 1.0029,
    1.0045, 1.0047,
    2.74, 3.20,
    3.20, 7.734,
    9.775, 9.87,
    27.09
]

# Create a logarithmic scale for color mapping
log_scale = np.log10(execution_times)
log_min, log_max = np.min(log_scale), np.max(log_scale)
colors = plt.cm.jet((log_scale - log_min) / (log_max - log_min))

# Creating the histogram with adjusted colors
fig, ax = plt.subplots(figsize=(18, 8))  # Increased width for better visibility
bars = ax.barh(languages, execution_times, color=colors)
plt.xlabel('Execution Time (s)')
plt.ylabel('Language / Framework')
plt.title('Execution Time Comparison for Windows 11 23H2')

# Create a colorbar with a logarithmic scale
sm = plt.cm.ScalarMappable(cmap='jet', norm=plt.Normalize(vmin=min(execution_times), vmax=max(execution_times)))
cbar = plt.colorbar(sm, ax=ax)
cbar.set_label('Execution Time (s)')

plt.tight_layout()
plt.show()

# %%
languages = [
    "NASM x64 DLL v2.16.01",
    "Cython v3.0.7",
    "Cython Full v3.0.7",
    "Dotnet Core v8.0.100",
    "C++ gcc version v13.2.0",
    "Javascript - nodeJS v21.5.0",
    "TypeScript ts-node v5.3.3",
    "TypeScript - compiled v21.5.0",
    "PyPy 7.3.14 with GCC 10.2.1 with Python 3.10.13",
    "Firefox v119",
    "TypeScript compiled Firefox v119",
    "Python 3.12.1"
]
execution_times = [
    0.1908,  # NASM x64 DLL v2.16.01
    1.0151,  # Cython v3.0.7
    1.0162,  # Cython Full v3.0.7
    1.0181,  # Dotnet Core v8.0.100
    1.0185,  # C++ gcc version v13.2.0
    2.59,    # Javascript - nodeJS v21.5.0
    3.21,    # TypeScript ts-node v5.3.3
    3.22,    # TypeScript - compiled v21.5.0
    3.450,   # PyPy 7.3.14 with GCC 10.2.1 with Python 3.10.13
    4.725,   # Firefox v119
    7.004,   # TypeScript compiled Firefox v119
    19.18    # Python 3.12.1
]

# Create a logarithmic scale for color mapping
log_scale = np.log10(execution_times)
log_min, log_max = np.min(log_scale), np.max(log_scale)
colors = plt.cm.jet((log_scale - log_min) / (log_max - log_min))

# Creating the histogram with adjusted colors
fig, ax = plt.subplots(figsize=(18, 8))  # Increased width for better visibility
bars = ax.barh(languages, execution_times, color=colors)
plt.xlabel('Execution Time (s)')
plt.ylabel('Language / Framework')
plt.title('Execution Time Comparison for Ubuntu 23.10')

# Create a colorbar with a logarithmic scale
sm = plt.cm.ScalarMappable(cmap='jet', norm=plt.Normalize(vmin=min(execution_times), vmax=max(execution_times)))
cbar = plt.colorbar(sm, ax=ax)
cbar.set_label('Execution Time (s)')

plt.tight_layout()
plt.show()

# %%
languages = [
    "PyPy v7.3.14 with MSC v.1929 with python v3.10.13",
    "Python 3.12.1",
    "Cython v3.0.7",
    "Cython Full v3.0.7",
    "C++ MSVC x64 v19.38.33133 / Linker v14.38.33133.0",
    "DotnetCore v8.0.100",
    "Javascript - nodeJS v21.5.0",
    "TypeScript - compiled v21.5.0",
    "TypeScript ts-node v5.3.3",
    "Firefox v122.0b4",
    "TypeScript compiled Firefox v122.0b4",
    "ASM - MASM x64 v14.38.33133.0",
    "ASM - NASM x64 v2.16.01"
]

normalized = [
    10.05,
    10.05,
    11.82,
    17.14,
    18.03,
    20.1,
    31.03,
    31.63,
    31.63,
    31.03,
    31.63,
    100.0,
    99.9
]

# Create a logarithmic scale for color mapping
log_scale = np.log10(normalized)
log_min, log_max = np.min(log_scale), np.max(log_scale)
colors = plt.cm.jet((log_scale - log_min) / (log_max - log_min))

# Creating the histogram with adjusted colors
fig, ax = plt.subplots(figsize=(18, 8))  # Increased width for better visibility
bars = ax.barh(languages, normalized, color=colors)
plt.xlabel('Difficulty (Normalized)')
plt.ylabel('Language / Framework')
plt.title('Difficulty Comparison for coding the solution')

# Create a colorbar with a logarithmic scale
sm = plt.cm.ScalarMappable(cmap='jet', norm=plt.Normalize(vmin=min(normalized), vmax=max(normalized)))
cbar = plt.colorbar(sm, ax=ax)
cbar.set_label('Execution Time (s)')

plt.tight_layout()
plt.show()

# %%
languages = [
    "ASM - MASM x64 v14.38.33133.0",
    "ASM - NASM x64 v2.16.01",
    "C++ MSVC x64 v19.38.33133 / Linker v14.38.33133.0",
    "Javascript - nodeJS v21.5.0",
    "TypeScript - compiled v21.5.0",
    "TypeScript ts-node v5.3.3",
    "Cython v3.0.7",
    "Cython Full v3.0.7",
    "Python 3.12.1",
    "PyPy v7.3.14 with MSC v.1929 with python v3.10.13",
    "DotnetCore v8.0.100",
    "Firefox v122.0b4",
    "TypeScript compiled Firefox v122.0b4"
]

log_sizes = [
    0.48742121135947436,
    0.48742121135947436,
    1.051692641798037,
    3.92592508674366,
    3.92592508674366,
    3.92592508674366,
    4.321629908943605,
    4.321629908943605,
    4.321629908943605,
    5.049198847369965,
    5.020599913279624,
    5.3711818191280365,
    5.3711818191280365
]

# Create a logarithmic scale for color mapping
log_scale = np.log10(log_sizes)
log_min, log_max = np.min(log_scale), np.max(log_scale)
colors = plt.cm.jet((log_scale - log_min) / (log_max - log_min))

# Creating the histogram with adjusted colors
fig, ax = plt.subplots(figsize=(18, 8))  # Increased width for better visibility
bars = ax.barh(languages, log_sizes, color=colors)
plt.xlabel('Size (kB) - log scale')
plt.ylabel('Language / Framework')
plt.title('Size of the package to execute the solution')

# Create a colorbar with a logarithmic scale
sm = plt.cm.ScalarMappable(cmap='jet', norm=plt.Normalize(vmin=min(log_sizes), vmax=max(log_sizes)))
cbar = plt.colorbar(sm, ax=ax)
cbar.set_label('Execution Time (s)')

plt.tight_layout()
plt.show()
